# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ball_by_ball = pd.read_csv('data/training_dataset/DataSet/IPL_Ball_by_Ball_2008_2022.csv')
match_result = pd.read_csv('data/training_dataset/DataSet/IPL_Matches_Result_2008_2022.csv')

# %%
ball_by_ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match_result.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
len(ball_by_ball.ID.unique())
# Out:
# 950

# %%
len(match_result.ID.unique())
# Out:
# 950

# %%
len(ball_by_ball)
# Out:
# 225954

# %%
len(match_result)
# Out:
# 950

# %%
match_result.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
match_result.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
match_result.Team2.unique()
# Out:
# array(['Gujarat Titans', 'Rajasthan Royals', 'Lucknow Super Giants',
#        'Punjab Kings', 'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad', 'Delhi Capitals',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
for index, i in enumerate(match_result.Team1.unique()):
    if i not in match_result.Team2.unique():
        print(i)
    else:
        print(f'{i} is in both. Index: {index+ 1}')
# Out:
# Rajasthan Royals is in both. Index: 1
# Royal Challengers Bangalore is in both. Index: 2
# Sunrisers Hyderabad is in both. Index: 3
# Delhi Capitals is in both. Index: 4
# Chennai Super Kings is in both. Index: 5
# Gujarat Titans is in both. Index: 6
# Lucknow Super Giants is in both. Index: 7
# Kolkata Knight Riders is in both. Index: 8
# Punjab Kings is in both. Index: 9
# Mumbai Indians is in both. Index: 10
# Kings XI Punjab is in both. Index: 11
# Delhi Daredevils is in both. Index: 12
# Rising Pune Supergiant is in both. Index: 13
# Gujarat Lions is in both. Index: 14
# Rising Pune Supergiants is in both. Index: 15
# Pune Warriors is in both. Index: 16
# Deccan Chargers is in both. Index: 17
# Kochi Tuskers Kerala is in both. Index: 18

# %%
match_result.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ball_by_ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
for match_id in match_result['ID']:
    print(f"Ball by ball details for match ID: {match_id}")
    print(ball_by_ball[ball_by_ball['ID'] == match_id])
# Out:
# Ball by ball details for match ID: 1312200
#           ID  innings  overs  ballnumber        batter          bowler  \
# 0    1312200        1      0           1   YBK Jaiswal  Mohammed Shami
# 1    1312200        1      0           2   YBK Jaiswal  Mohammed Shami
# 2    1312200        1      0           3    JC Buttler  Mohammed Shami
# 3    1312200        1      0           4   YBK Jaiswal  Mohammed Shami
# 4    1312200        1      0           5   YBK Jaiswal  Mohammed Shami
# ..       ...      ...    ...         ...           ...             ...
# 228  1312200        2     17           3     DA Miller        R Ashwin
# 229  1312200        2     17           4  Shubman Gill        R Ashwin
# 230  1312200        2     17           5  Shubman Gill        R Ashwin
# 231  1312200        2     17           6     DA Miller        R Ashwin
# 232  1312200        2     18           1  Shubman Gill        OC McCoy
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
ball_by_ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match_result.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ball_by_ball = ball_by_ball[ball_by_ball["overs"]>=6]

# %%
ball_by_ball
# Out:
#              ID  innings  overs  ballnumber      batter       bowler  \
# 36      1312200        1      6           1   SV Samson  LH Ferguson
# 37      1312200        1      6           2   SV Samson  LH Ferguson
# 38      1312200        1      6           3  JC Buttler  LH Ferguson
# 39      1312200        1      6           4  JC Buttler  LH Ferguson
# 40      1312200        1      6           5  JC Buttler  LH Ferguson
# ...         ...      ...    ...         ...         ...          ...
# 225949   335982        2     14           5     P Kumar     I Sharma
# 225950   335982        2     14           6    SB Joshi     I Sharma
# 225951   335982        2     14           7     P Kumar     I Sharma
# 225952   335982        2     15           1    SB Joshi    LR Shukla
# 225953   335982        2     15           2    SB Joshi    LR Shukla
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# 36      JC Buttler        NaN            0           0          0
# ...

# %%
len(ball_by_ball.ID.unique())
# Out:
# 949

# %%
len(match_result.ID.unique())
# Out:
# 950

# %%
# Get the set of unique match IDs in ball_by_ball and match_result
ball_by_ball_match_ids = set(ball_by_ball.ID.unique())
match_result_match_ids = set(match_result.ID.unique())

# Find the match ID present in match_result but not in ball_by_ball
missing_match_id = match_result_match_ids - ball_by_ball_match_ids

# Print the missing match ID
print(f"Missing match ID: {missing_match_id}")
# Out:
# Missing match ID: {1178424}

# %%
match_result["ID"][1178424]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 1178424 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 match_result["ID"][1178424]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
# ...

# %%
match_result[match_result["ID"]==1178424]
# Out:
#           ID       City        Date Season MatchNumber  \
# 205  1178424  Bengaluru  2019-04-30   2019          49
#
#                            Team1             Team2                  Venue  \
# 205  Royal Challengers Bangalore  Rajasthan Royals  M.Chinnaswamy Stadium
#
#            TossWinner TossDecision SuperOver WinningTeam      WonBy  Margin  \
# 205  Rajasthan Royals        field       NaN         NaN  NoResults     NaN
#
#     method Player_of_Match                                       Team1Players  \
# 205    NaN             NaN  ['V Kohli', 'AB de Villiers', 'MP Stoinis', 'H...
#
#                                           Team2Players   Umpire1    Umpire2
# 205  ['SV Samson', 'LS Livingstone', 'AM Rahane', '...  NJ Llong  UV Gandhe

# %%
match_result = match_result[match_result["ID"] != 1178424]
match_result.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
len(match_result.ID.unique())
# Out:
# 949

# %%
len(ball_by_ball.ID.unique())
# Out:
# 949

# %%
match_result.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
ball_by_ball.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')
